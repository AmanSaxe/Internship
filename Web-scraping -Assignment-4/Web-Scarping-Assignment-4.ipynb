# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import time
import re

# %%
# let's first connect to web driver
driver=webdriver.Chrome(r'C:\Users\DELL\Downloads\chromedriver_win32\chromedriver.exe')

# %% [markdown]
# ### Q1.Scrape the details of most viewed videos on YouTube from Wikipedia.
# ### Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# ### You need to find following details:
# ### A) Rank
# ### B) Name
# ### C) Artist
# ### D) Upload date
# ### E) Views

# %%
url="https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)

# %%
Rank=[]
Name=[]
Artist=[]
Views=[]
Upload_date=[]
try:
    ranktags=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody[1]/tr/td[1]')
    for i in ranktags[:30]:
        Rank.append(i.text)
except NoSuchElementException as e:
    print("Exception Raised ",e)
    ranktags=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody[1]/tr/td[1]')
    for i in ranktags[:30]:
        Rank.append(i.text)

try:
    nametags=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody[1]/tr/td[2]')
    for i in nametags[:30]:
        Name.append(i.text)
except NoSuchElementException as e:
    print("Exception Raised ",e)
    ranktags=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody[1]/tr/td[2]')
    for i in nametags[:30]:
        Name.append(i.text)

try:
    artisttags=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody[1]/tr/td[3]')
    for i in artisttags[:30]:
        Artist.append(i.text)
except NoSuchElementException as e:
    print("Exception Raised ",e)
    artisttags=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody[1]/tr/td[2]')
    for i in artisttags[:30]:
        Artist.append(i.text)

try:
    viewstags=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody[1]/tr/td[4]')
    for i in viewstags[:30]:
        Views.append(i.text)
except NoSuchElementException as e:
    print("Exception Raised ",e)
    viewstags=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody[1]/tr/td[4]')
    for i in viewstags[:30]:
        Views.append(i.text)

try:
    datetags=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody[1]/tr/td[5]')
    for i in datetags[:30]:
        Upload_date.append(i.text)
except NoSuchElementException as e:
    print("Exception Raised ",e)
    datetags=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody[1]/tr/td[5]')
    for i in datetags[:30]:
        Upload_date.append(i.text)
        
video=pd.DataFrame({'Rank':Rank,'Name':Name,'Artist':Artist,'Views':Views,'Upload Date':Upload_date})
video
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.  "Learning Colors – Colorful Eggs on a Farm"[21]
# 7    8.   "Masha and the Bear – Recipe for Disaster"[22]
# 8    9.                "Phonics Song with Two Words"[23]
# 9   10.                                "Uptown Funk"[24]
# 10  11.                              "Gangnam Style"[25]
# 11  12.                             "Dame Tu Cosita"[30]
# 12  13.                          "Wheels on the Bus"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# ...

# %% [markdown]
# ### Q2. Scrape the details team India’s international fixtures from bcci.tv.
# ### Url = https://www.bcci.tv/.
# ### You need to find following details:
# ### A) Match title (I.e. 1st ODI)
# ### B) Series
# ### C) Place
# ### D) Date
# ### E) Time
# ### Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
url='https://www.bcci.tv/'
driver.get(url)

# %%
try:
    international_btn=driver.find_element_by_xpath('/html/body/nav/div/div[2]/ul[1]/li[2]/a')
    international_btn.click()
except NoSuchElementException as e:
    print("Exception Raised ",e)
    driver.get(url)
    international_btn=driver.find_element_by_xpath('/html/body/nav/div/div[2]/ul[1]/li[2]/a')
    international_btn.click()

# %%
Match_title=[]
Series=[]
Place=[]
Date=[]
Time=[]
try:
    titletags=driver.find_elements_by_xpath('//span[@class="matchOrderText ng-binding ng-scope"]')
    for i in titletags:
        Match_title.append(i.text)
except NoSuchElementException as e:
    print("Exception Raised ",e)
    titletags=driver.find_elements_by_xpath('//span[@class="matchOrderText ng-binding ng-scope"]')
    for i in titletags:
        Match_title.append(i.text)

try:
    seriestags=driver.find_elements_by_xpath('//span[@class="ng-binding"]')
    for i in seriestags:
        Series.append(i.text)
except NoSuchElementException as e:
    print("Exception Raised ",e)
    seriestags=driver.find_elements_by_xpath('//span[@class="ng-binding"]')
    for i in seriestags:
        Series.append(i.text)

try:
    placetags=driver.find_elements_by_xpath('//span[@class="ng-binding ng-scope"]')
    for i in placetags:
        Place.append(i.text)
except NoSuchElementException as e:
    print("Exception Raised ",e)
    placetags=driver.find_elements_by_xpath('//span[@class="ng-binding ng-scope"]')
    for i in placetags:
        Place.append(i.text)

try:
    datetags=driver.find_elements_by_xpath('//h5[@class="ng-binding"]')
    for i in datetags:
        Date.append(i.text)
except NoSuchElementException as e:
    print("Exception Raised ",e)
    datetags=driver.find_elements_by_xpath('//h5[@class="ng-binding"]')
    for i in datetags:
        Date.append(i.text)

try:
    timetags=driver.find_elements_by_xpath('//h5[@class="text-right ng-binding"]')
    for i in timetags:
        Time.append(i.text)
except NoSuchElementException as e:
    print("Exception Raised ",e)
    timetags=driver.find_elements_by_xpath('//h5[@class="text-right ng-binding"]')
    for i in timetags:
        Time.append(i.text)
        
fixtures=pd.DataFrame({'Match Title':Match_title,'Series':Series,'Place':Place,'Date':Date,'Time':Time})
fixtures
# Out:
#   Match Title                                           Series  \
# 0   5th ODI -  INDIA WOMEN TOUR OF NEW ZEALAND ODI SERIES 2022
# 1  1st T20I -          SRI LANKA TOUR OF INDIA T20 SERIES 2022
# 2  2nd T20I -          SRI LANKA TOUR OF INDIA T20 SERIES 2022
# 3  3rd T20I -          SRI LANKA TOUR OF INDIA T20 SERIES 2022
# 4  1st Test -         SRI LANKA TOUR OF INDIA TEST SERIES 2022
# 5   1st ODI -                        ICC WOMENS WORLD CUP 2022
# 6   2nd ODI -                        ICC WOMENS WORLD CUP 2022
# 7  2nd Test -         SRI LANKA TOUR OF INDIA TEST SERIES 2022
#
#                                                Place         Date  \
# 0                                  John Davies Oval,  24 FEB 2022
# 1  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...  24 FEB 2022
# 2      Himachal Pradesh Cricket Association Stadium,  26 FEB 2022
# 3      Himachal Pradesh Cricket Association Stadium,  27 FEB 2022
# ...

# %% [markdown]
# ### Q3. Scrape the details of selenium exception from guru99.com.
# ### Url = https://www.guru99.com/
# ### You need to find following details:
# ### A) Name
# ### B) Description
# ### Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
url='https://www.guru99.com/'
driver.get(url)

# %%
try:
    seleniumbtn=driver.find_element_by_xpath('/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[2]/div[1]/div/ul[1]/li[3]/a')
    seleniumbtn.click()
    time.sleep(2)
    exptnbtn=driver.find_element_by_xpath('/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a')
    exptnbtn.click()
except  NoSuchElementException as e:
    print("Exception Raised ",e)
    driver.get(url)
    seleniumbtn=driver.find_element_by_xpath('/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[2]/div[1]/div/ul[1]/li[3]/a')
    seleniumbtn.click()
    time.sleep(2)
    exptnbtn=driver.find_element_by_xpath('/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a')
    exptnbtn.click()

# %%
Name=[]
try:
    nametags=driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[1]')
    for i in nametags:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('-')
Description=[]
try:
    desctags=driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[2]')
    for i in desctags:
        Description.append(i.text)
except NoSuchElementException:
    Description.append('-')

# %%
selenium=pd.DataFrame({'Exception Name':Name,'Description':Description})
selenium
# Out:
#                          Exception Name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %% [markdown]
# ### Q4. Scrape the details of State-wise GDP of India from statisticstime.com.
# ### Url = http://statisticstimes.com/
# ### You have to find following details:
# ### A) Rank
# ### B) State
# ### C) GSDP
# ### D) GSDP
# ### E) Share
# ### F) GDP($ billion)
# ### Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
url = 'https://www.statisticstimes.com/'
driver.get(url)

# %%
try:
    economybtn=driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/button')
    economybtn.click()
    indiabtn=driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')
    indiabtn.click()
    gdpbtn=driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
    gdpbtn.click()
except NoSuchElementException as e:
    print("Exception Raised ",e)
    driver.get(url)
    economybtn=driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/button')
    economybtn.click()
    indiabtn=driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')
    indiabtn.click()
    gdpbtn=driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
    gdpbtn.click()

# %%
Rank=[]
State=[]
GSDP_1920=[]
GSDP_1819=[]
Share=[]
GDP_billion=[]
try:
    ranktags=driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[1]')
    for i in ranktags:
        Rank.append(i.text)
except NoSuchElementException as e:
    print("Exception Raised ",e)
    ranktags=driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[1]')
    for i in ranktags:
        Rank.append(i.text)

try:
    statetags=driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[2]')
    for i in statetags:
        State.append(i.text)
except NoSuchElementException as e:
    print("Exception Raised ",e)
    statetags=driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[2]')
    for i in statetags:
        State.append(i.text)

try:
    gsdptags=driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[3]')
    for i in gsdptags:
        GSDP_1920.append(i.text)
except NoSuchElementException as e:
    print("Exception Raised ",e)
    gsdptags=driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[3]')
    for i in gsdptags:
        GSDP_1920.append(i.text)

try:
    gsdptags=driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[4]')
    for i in gsdptags:
        GSDP_1819.append(i.text)
except NoSuchElementException as e:
    print("Exception Raised ",e)
    gsdptags=driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[4]')
    for i in gsdptags:
        GSDP_1819.append(i.text)

try:
    sharetags=driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[5]')
    for i in sharetags:
        Share.append(i.text)
except NoSuchElementException as e:
    print("Exception Raised ",e)
    sharetags=driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[5]')
    for i in sharetags:
        Share.append(i.text)

try:
    gdptags=driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[6]')
    for i in gdptags:
        GDP_billion.append(i.text)
except NoSuchElementException as e:
    print("Exception Raised ",e)
    gdptags=driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[6]')
    for i in gdptags:
        GDP_billion.append(i.text)
        
GDP=pd.DataFrame({'Rank':Rank,'State':State,'GSDP 19-20':GSDP_1920,'GSDP 18-19':GSDP_1819,'Share':Share,'GDP($ billion)':GDP_billion})
GDP
# Out:
#    Rank                      State GSDP 19-20 GSDP 18-19   Share  \
# 0     1                Maharashtra          -  2,632,792  13.94%
# 1     2                 Tamil Nadu  1,845,853  1,630,208   8.63%
# 2     3              Uttar Pradesh  1,687,818  1,584,764   8.39%
# 3     4                    Gujarat          -  1,502,899   7.96%
# 4     5                  Karnataka  1,631,977  1,493,127   7.91%
# 5     6                West Bengal  1,253,832  1,089,898   5.77%
# 6     7                  Rajasthan  1,020,989    942,586   4.99%
# 7     8             Andhra Pradesh    972,782    862,957   4.57%
# 8     9                  Telangana    969,604    861,031   4.56%
# 9    10             Madhya Pradesh    906,672    809,592   4.29%
# 10   11                     Kerala          -    781,653   4.14%
# 11   12                      Delhi    856,112    774,870   4.10%
# 12   13                    Haryana    831,610    734,163   3.89%
# ...

# %% [markdown]
# ### Q5. Scrape the details of trending repositories on Github.com.
# ### Url = https://github.com/
# ### You have to find the following details:
# ### A) Repository title
# ### B) Repository description
# ### C) Contributors count
# ### D) Language used

# %%
url='https://github.com/'
driver.get(url)

# %%
try:
    explorebtn=driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary')
    explorebtn.click()
    trendingbtn=driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a')
    trendingbtn.click()
except  NoSuchElementException as e:
    print("Exception Raised ",e)
    driver.get(url)
    explorebtn=driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary')
    explorebtn.click()
    trendingbtn=driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a')
    trendingbtn.click()

# %%
Urls=[]
urltags=driver.find_elements_by_xpath('//h1[@class="h3 lh-condensed"]/a')
for i in urltags:
    Urls.append(i.get_attribute("href"))

# %%
Title=[]
try:
    titletags=driver.find_elements_by_xpath('//h1[@class="h3 lh-condensed"]')
    for i in titletags:
        Title.append(i.text)
except NoSuchElementException as e:
    print("Exception Raised ",e)
    titletags=driver.find_elements_by_xpath('//h1[@class="h3 lh-condensed"]')
    for i in titletags:
        Title.append(i.text)
Description=[]
try:
    decriptiontags=driver.find_elements_by_xpath('//p[@class="col-9 color-fg-muted my-1 pr-4"]')
    for i in decriptiontags:
        Description.append(i.text)
except NoSuchElementException as e:
    print("Exception Raised ",e)
    decriptiontags=driver.find_elements_by_xpath('//p[@class="col-9 color-fg-muted my-1 pr-4"]')
    for i in descriptiontags:
        Description.append(i.text)
Contricount=[]
try:
    counttags=driver.find_elements_by_xpath('//div[@class="f6 color-fg-muted mt-2"]/a[2]')
    for i in counttags:
        Contricount.append(i.text)
except NoSuchElementException as e:
    print("Exception Raised ",e)
    counttags=driver.find_elements_by_xpath('//div[@class="f6 color-fg-muted mt-2"]/a[2]')
    for i in counttags:
        Contricount.append(i.text)
Language=[]
try:
    langtags=driver.find_elements_by_xpath('//span[@class="d-inline-block ml-0 mr-3"]/span[2]')
    for i in langtags:
        Language.append(i.text)
except NoSuchElementException:
    Language.append('-')

# %%
repo=pd.DataFrame({'Title':Title,'Description':Description,'Contributors':Contricount,'Language':Language})
repo
# Out:
#                                                Title  \
# 0                           louisyoungx / JD-SHOPPER
# 1                         github / advisory-database
# 2                                  netdata / netdata
# 3                               jrouwe / JoltPhysics
# 4               KumarRobotics / kr_autonomous_flight
# 5                              nusr / hacker-laws-zh
# 6                   anderspitman / awesome-tunneling
# 7                     labuladong / fucking-algorithm
# 8                             withfig / autocomplete
# 9                                commaai / openpilot
# 10                                planetscale / beam
# 11                    KurtBestor / Hitomi-Downloader
# 12                             VoronDesign / Voron-2
# 13                     vueComponent / ant-design-vue
# 14                SebLague / Geographical-Adventures
# 15                                tiangolo / fastapi
# 16                             H5-Dooring / dooringx
# ...

# %% [markdown]
# ### 6. Scrape the details of top 100 songs on billiboard.com.
# ### Url = https:/www.billboard.com/
# ### You have to find the following details:
# ### A) Song name
# ### B) Artist name
# ### C) Last week rank
# ### D) Peak rank
# ### E) Weeks on board
# ### Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
url='https://www.billboard.com/'
driver.get(url)

# %%
try:
    chartbtn=driver.find_element_by_xpath('/html/body/div[4]/header/div[1]/div/div/div[2]/div/nav/ul/li[1]/a')
    chartbtn.click()
    hotbtn=driver.find_element_by_xpath('/html/body/div[4]/main/div[2]/div[1]/div[1]/div/div/div[1]/div[1]/div[2]/span/a')
    hotbtn.click()
except NoSuchElementException as e:
    print("Exception Raised ",e)
    driver.get(url)
    chartbtn=driver.find_element_by_xpath('/html/body/div[4]/header/div[1]/div/div/div[2]/div/nav/ul/li[1]/a')
    chartbtn.click()
    hotbtn=driver.find_element_by_xpath('/html/body/div[4]/main/div[2]/div[1]/div[1]/div/div/div[1]/div[1]/div[2]/span/a')
    hotbtn.click()

# %%
Rank=[]
try:
    ranktags=driver.find_elements_by_xpath('//span[@class="c-label  a-font-primary-bold-l u-font-size-32@tablet u-letter-spacing-0080@tablet"]')
    for i in ranktags:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')
Song_name=[]
try:
    nametags=driver.find_elements_by_xpath('//h3[@class="c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 u-font-size-23@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-245 u-max-width-230@tablet-only u-letter-spacing-0028@tablet"]')
    for i in nametags:
        Song_name.append(i.text)
except NoSuchElementException:
    Song_name.append('-')
try:
    nametag=driver.find_elements_by_xpath('//h3[@class="c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only"]')
    for i in nametag:
        Song_name.append(i.text)
except NoSuchElementException:
    Song_name.append('-') 
Artist_name=[]
try:
    arnametags=driver.find_elements_by_xpath('//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet"]')
    for i in arnametags:
        Artist_name.append(i.text)
except NoSuchElementException:
    Artist_name.append('-')
try:
    arnametag=driver.find_elements_by_xpath('//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"]')
    for i in arnametag:
        Artist_name.append(i.text)
except NoSuchElementException:
    Artist_name.append('-')    
Weekrank=[]

try:
    lastranks=driver.find_elements_by_xpath('//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max"]/span[1]')
    for i in lastranks:
        Weekrank.append(i.text)
except NoSuchElementException:
    Weekrank.append('-')
Lastweek_rank=[]
for i in Weekrank[:200:2]:
    Lastweek_rank.append(i)
weeksonboard=[]
for i in Weekrank[1::2]:
    weeksonboard.append(i)
column=[]
try:
    columntags=driver.find_elements_by_xpath('//li[@class="o-chart-results-list__item // a-chart-bg-color a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-background-color-grey-lightest lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-hidden@mobile-max"]')
    for i in columntags:
        column.append(i.text)
except NoSuchElementException:
    column.append('-') 
Peak_rank=[]
for i in column[1::2]:
    Peak_rank.append(i)

# %%
topsongs=pd.DataFrame({'Rank':Rank,'Song name':Song_name,'Artist name':Artist_name,'Last week rank':Lastweek_rank,'Weeks on board':weeksonboard,'Peak rank':Peak_rank})
topsongs
# Out:
#    Rank                        Song name  \
# 0     1        We Don't Talk About Bruno
# 1     2                       Heat Waves
# 2     3                       Easy On Me
# 3     4                          abcdefu
# 4     5                             Stay
# ..  ...                              ...
# 95   96  All Too Well (Taylor's Version)
# 96   97       Come Back As A Country Boy
# 97   98                             Iffy
# 98   99                       Home Sweet
# 99  100                         Too Easy
#
#                                           Artist name Last week rank  \
# 0   Carolina Gaitan, Mauro Castillo, Adassa, Rhenz...              1
# 1                                       Glass Animals              4
# 2                                               Adele              3
# 3                                               GAYLE              7
# 4                       The Kid LAROI & Justin Bieber              5
# ...

# %% [markdown]
# ### Q7. Scrape the details of Data science recruiters from naukri.com.
# ### Url = https://www.naukri.com/
# ### You have to find the following details:
# ### A) Name
# ### B) Designation
# ### C) Company
# ### D) Skills they hire for
# ### E) Location
# ### Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# ### click on search. All this should be done through code

# %%
url='https://www.naukri.com/hr-recruiters-consultants'
driver.get(url)

# %%
search_field=driver.find_element_by_xpath('//input[@class="sugInp"]')
search_field.send_keys('Data Science')

# %%
search_btn=driver.find_element_by_xpath('//button[@class="fl qsbSrch blueBtn"]')
search_btn.click()

# %%
recruiters_url=[]
urltags=driver.find_elements_by_xpath('//div[@class="outerRecSec"]/div/div[1]/div[1]/p/a[1]')
for i in urltags:
    recruiters_url.append(i.get_attribute('href'))

# %%
Name=[]
Designation=[]
Company=[]
Skills=[]
Location=[]
for url in recruiters_url:
    driver.get(url)
    try:
        nametags=driver.find_element_by_xpath('//h1[@class="fl ellipsis wLimit hd"]')
        Name.append(nametags.text)
    except NoSuchElementException:
        Name.append('-')
    time.sleep(1)
    try:
        desigtags=driver.find_element_by_xpath('//div[@class="ellipsis"]')
        Designation.append(desigtags.text)
    
    except NoSuchElementException:
        Designation.append('-')    
    time.sleep(1)    
    try:
        companytags=driver.find_element_by_xpath('//div[@class="rFrame fl infoWrapper"]/div[4]/a')
        Company.append(companytags.text)
    except NoSuchElementException:
        Company.append('-')
    time.sleep(1)    
    try:
        skilltags=driver.find_element_by_xpath('//div[@class="fl lPortn"]/p[1]')
        Skills.append(skilltags.text)
    except NoSuchElementException:
        Skills.append('-') 
    time.sleep(1)
    try:
        loctags=driver.find_element_by_xpath('//div[@class="rFrame fl infoWrapper"]/div[5]/a')
        Location.append(loctags.text)
    except NoSuchElementException:
        Location.append('-')

# %%
recruiters=pd.DataFrame({'Name':Name,'Designation':Designation,'Company':Company,'Skills':Skills,'Location':Location})
recruiters
# Out:
#                                                  Name  \
# 0                                        Aakash Harit
# 1                                shravan Kumar Gaddam
# 2                            MARSIAN Technologies LLP
# 3                                        Anik Agrawal
# 4                                        subhas patel
# 5   Abhishek - Only Analytics Hiring - India and APAC
# 6     Institute for Financial Management and Research
# 7                                         Balu Ramesh
# 8                                       Asif Lucknowi
# 9                                     InstaFinancials
# 10                                     Priyanka Akiri
# 11                                    Kalpana Dumpala
# 12                                            Mubarak
# 13                                     Kushal Rastogi
# 14                                 Mahesh Babu Channa
# 15                                    Sakshi Chhikara
# ...

# %% [markdown]
# ### Q8. Scrape the details of Highest selling novels.
# ### Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# ### You have to find the following details:
# ### A) Book name
# ### B) Author name
# ### C) Volumes sold
# ### D) Publisher
# ### E) Genre

# %% [markdown]
# #### This link is not reachable

# %% [markdown]
# ### 9. Scrape the details most watched tv series of all time from imdb.com.
# ### Url = https://www.imdb.com/list/ls095964455/
# ### You have to find the following details:
# ### A) Name
# ### B) Year span
# ### C) Genre
# ### D) Run time
# ### E) Ratings
# ### F) Votes

# %%
url='https://www.imdb.com/list/ls095964455/'
driver.get(url)

# %%
Name=[]
Year_span=[]
Genre=[]
Run_time=[]
Ratings=[]
Votes=[]
try:
    nametags=driver.find_elements_by_xpath('//div[@class="lister-item mode-detail"]/div[2]/h3/a')
    for i in nametags:
        Name.append(i.text)
except NoSuchElementException:
    print("Exception Raised ",e)
    nametags=driver.find_elements_by_xpath('//div[@class="lister-item mode-detail"]/div[2]/h3/a')
    for i in nametags:
        Name.append(i.text)
        
try:
    yeartags=driver.find_elements_by_xpath('//div[@class="lister-item mode-detail"]/div[2]/h3/span[2]')
    for i in yeartags:
        Year_span.append(i.text)
except NoSuchElementException:
    print("Exception Raised ",e)
    yeartags=driver.find_elements_by_xpath('//div[@class="lister-item mode-detail"]/div[2]/h3/span[2]')
    for i in yeartags:
        Year_span.append(i.text)
        
try:
    genretags=driver.find_elements_by_xpath('//div[@class="lister-item mode-detail"]/div[2]/p/span[5]')
    for i in genretags:
        Genre.append(i.text)
except NoSuchElementException:
    print("Exception Raised ",e)
    genretags=driver.find_elements_by_xpath('//div[@class="lister-item mode-detail"]/div[2]/p/span[5]')
    for i in genretags:
        Genre.append(i.text)
        
try:
    timetags=driver.find_elements_by_xpath('//div[@class="lister-item mode-detail"]/div[2]/p/span[3]')
    for i in timetags:
        Run_time.append(i.text)
except NoSuchElementException:
    print("Exception Raised ",e)
    timetags=driver.find_elements_by_xpath('//div[@class="lister-item mode-detail"]/div[2]/p/span[3]')
    for i in timetags:
        Run_time.append(i.text)
        
try:
    ratingstag=driver.find_elements_by_xpath('//div[@class="lister-item mode-detail"]/div[2]/div[1]/div/span[2]')
    for i in ratingstag:
        Ratings.append(i.text)
except NoSuchElementException:
    print("Exception Raised ",e)
    ratingstag=driver.find_elements_by_xpath('//div[@class="lister-item mode-detail"]/div[2]/div[1]/div/span[2]')
    for i in ratingstag:
        Ratings.append(i.text)
        
try:
    votetags=driver.find_elements_by_xpath('//div[@class="lister-item mode-detail"]/div[2]/p[4]/span[2]')
    for i in votetags:
        Votes.append(i.text)
except NoSuchElementException:
    print("Exception Raised ",e)
    votetags=driver.find_elements_by_xpath('//div[@class="lister-item mode-detail"]/div[2]/p[4]/span[2]')
    for i in votetags:
        Votes.append(i.text)

# %%
imbd=pd.DataFrame({'Name':Name,'Year span':Year_span,'Genre':Genre,'Run time':Run_time,'Ratings':Ratings,'Votes':Votes})
imbd
# Out:
#                               Name    Year span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run time Ratings      Votes
# 0    57 min     9.2  1,956,983
# ...

# %% [markdown]
# ### Q10. Details of Datasets from UCI machine learning repositories.
# ### Url = https://archive.ics.uci.edu/
# ### You have to find the following details:
# ### A) Dataset name
# ### B) Data type
# ### C) Task
# ### D) Attribute type
# ### E) No of instances
# ### F) No of attribute
# ### G) Year
# ### Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
url='https://archive.ics.uci.edu/ml/index.php'
driver.get(url)

# %%
datasetbtn=driver.find_element_by_xpath('/html/body/table[2]/tbody/tr/td/span/b/a')
datasetbtn.click()

# %%
Dataset_name=[]
Data_type=[]
Task=[]
Attribute_type=[]
Instances=[]
Attribute=[]
Year=[]
Table=[]
try:
    tabletags=driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr')
    for i in tabletags[1:]:
        Table.append(i.text.split("\n"))
except NoSuchElementException:
    print("Exception Raised ",e)

# Making DataFrame
pd.DataFrame(Table,columns=['Dataset name','Data Type','Task','Attribute Type','No. Of Instances','No. Of Attributes','Year'])
# Out:
#                                           Dataset name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617    Influenza outbreak event prediction via Twit...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621    Image Recognition Task Execution Times in Mo...
#
#                       Data Type             Task               Attribute Type  \
# 0                 Multivariate   Classification   Categorical, Integer, Real
# 1                 Multivariate   Classification         Categorical, Integer
# ...
